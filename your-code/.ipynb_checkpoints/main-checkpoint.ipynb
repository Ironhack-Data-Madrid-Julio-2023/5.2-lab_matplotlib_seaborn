# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import pylab as plt 
import seaborn as sns
import warnings
import matplotlib.pyplot as plt



#Configuración
warnings.simplefilter('ignore')
plt.rcParams['figure.figsize'] = (12, 4)
# %matplotlib inline

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED

# Agrupar por la media de pasos por mes
steps_by_month_mean = fitbit.groupby('Months_encoded')['Steps'].mean()

# Calcular la mediana de pasos por mes
steps_by_month_median = fitbit.groupby('Months_encoded')['Steps'].median()

# Crear el gráfico de barras de la media de pasos por mes 
steps_by_month_mean.plot(kind='bar')

# Obtener el índice correspondiente a la mediana de pasos por mes
median_index = steps_by_month_mean.index[steps_by_month_mean == steps_by_month_median]

# Guardar el gráfico como imagen
plt.savefig('../figures/1.steps_by_month.png')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
avg_wow = fitbit.groupby('Work_or_Weekend')['Steps'].mean()
avg_wow
# Out:
# Work_or_Weekend
# 0    10064.238095
# 1    10144.572519
# Name: Steps, dtype: float64

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

for feature in features:
    plt.figure()
    plt.scatter(fitbit[feature], fitbit['Steps'])
    plt.xlabel(feature)
    plt.ylabel('Steps')
    plt.title(f'Scatter vs Steps')
    plt.savefig('../figures/2.figures_vs_Steps.png')

# Show the plots
plt.show()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

titanic.select_dtypes(include=['int', 'float'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES

titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

fig, ax = plt.subplots(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic['Age'], bins=10, edgecolor='black')

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')

plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# Crear subplots con 1 fila y 3 columnas
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

# Definir los intervalos para cada subplot
rang = [10, 20, 50]

# Trazar la distribución en cada subplot
for i, ax in enumerate(axes):
    ax.hist(titanic['Age'], bins=rang[i])
    ax.set_xlabel('Age')
    ax.set_ylabel('Frequency')
    ax.set_title(f'Range  {rang[i]}')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
El tamaño del bin en un histograma afecta la suavidad del gráfico 
y la cantidad de información mostrada. 

Bins más pequeños pueden 
revelar más detalles pero pueden hacer que el gráfico se vea 
irregular, mientras que bins más grandes suavizan el gráfico 
pero pueden ocultar detalles.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(titanic['Age'], kde=True)

sns.set(style="white", palette="viridis")


# Establecer etiquetas y título
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Edad en el Titanic')

plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

plt.hist(titanic['Gender'])

plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.title('Distribución de mujeres y hombres en el Titanic')

plt.show()

# %%
# Method 2 - seaborn

sns.histplot(titanic['Gender'])

# Establecer etiquetas y título
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.title('Distribución de mujeres y hombres en el Titanic')

plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
clase = titanic['Pclass'].value_counts()

colors = ['blue', 'red', 'green']

plt.bar(clase.index, clase.values, color=colors)

plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.title('Distribución de clases')

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.boxplot(titanic['Age'])

plt.ylabel('Age')
plt.title('Summary Statistics of Age')

plt.show()

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
La mediana (percentil 50) representa el valor en la línea central 
del rectángulo del box plot y en este caso indica que la mayor parte
de los datos se encuentran cerca de la mediana.

Los cuartiles (25% y 75% percentiles) son los límites inferior y 
superior del rectángulo del box plot representan el rango 
intercuartílico (IQR), que proporciona información sobre la 
dispersión de los datos. 
El IQR abarca el 50% central de los datos.

El bloxpot muestra gran cantidad de outliers
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
plt.violinplot(titanic['Age'])

plt.ylabel('Age')
plt.title('Summary Statistics and Distribution of Age')

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
El ancho del gráfico de violín en diferentes puntos representa 
la densidad de probabilidad de la distribución de los datos. 
Una parte más ancha indica una mayor densidad de puntos y, 
por lo tanto, una mayor probabilidad de que los valores de edad 
se encuentren en esa área.

El "grueso" del gráfico de violín muestra el rango 
intercuartílico (IQR), que contiene el 50% central de los datos.
La línea más gruesa en medio del gráfico indica la mediana 
(percentil 50).
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

plt.scatter(titanic['Age'], titanic['Fare'])

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Relationship between Fare and Age')

plt.show()

# %%
# Method 2 - seaborn
sns.scatterplot(data= titanic, x='Age', y='Fare')

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Relationship between Fare and Age')

plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.title('Correlation Matrix')

plt.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
A parte de las que tienen correlación de 1 porque son la misma 
variable, hay una relación de 0,56 en la tarifa que pagaron y la
clase en la que están.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic)
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.title('Summary Statistics of Age by Pclass')

plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col='Gender')

g.map(sns.histplot, 'Age')

g.set_axis_labels('Age', 'Count')
g.fig.suptitle('Distribution of Age by Gender')

plt.tight_layout()

plt.show()
