# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
#!pip install seaborn

# %%
# Libraries
import numpy as np
import pandas as pd
import pylab as plt 
import seaborn as sns

# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
median_month = fitbit.groupby('Months_encoded')['Steps'].median()
median_month.plot(kind= 'bar')
#plt.figure(figsize=(12, 4))
plt.xticks(rotation = 0);
plt.figure(figsize=(12, 4))# tiene que ir después
plt.savefig('figures/AVERAGE STEPS BY MONTH_.png')
plt.show()

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
median_day = fitbit.groupby('Work_or_Weekend')['Steps'].median()
median_day
# Out:
# Work_or_Weekend
# 0     9998.0
# 1    10445.5
# Name: Steps, dtype: float64

# %%
median_day.plot(kind='bar')


plt.xlabel('Day')
plt.ylabel('Median Steps')
plt.title('AVERAGE STEPS BY WORK_OR_WEEKEND')
plt.xticks(ticks=range(2), rotation=0)
plt.savefig('figures/AVERAGE STEPS BY WORK_OR_WEEKEND.png')
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
x = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for e, x in enumerate(x):
    axs[e].scatter(fitbit[x], fitbit['Steps'])

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info() # es mejor
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=('float64','int64'))
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(15,5))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fgs, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].hist(titanic['Age'], bins= 10)
axs[1].hist(titanic['Age'], bins= 20)
axs[2].hist(titanic['Age'], bins= 50);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
plt.figure(figsize=(10, 5))
sns.histplot(titanic['Age'], bins=20);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic.groupby('Gender').count()['Name'].plot(kind='bar',
        figsize = (10, 5),
        title = 'Gender')
# Out:
# <Axes: title={'center': 'Gender'}, xlabel='Gender'>

# %%
# Method 2 - seaborn
# your code here
plt.figure(figsize=(10, 5))
sns.countplot(x='Gender', data=titanic)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
plt.figure(figsize=(10, 5))
sns.countplot(x='Pclass', data=titanic)
plt.title('Pclass Distribution')
plt.xlabel('PClass')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.figure(figsize=(10, 5))
sns.boxplot(x=titanic['Age'])
plt.title('Age plot')
plt.xlabel('Age')
plt.show()

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
Most of the people were over 20 and under 40 years.Few people had more than 60 years

"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(x="Age", data = titanic)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
Another form to see the information, not really new information
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.figure(figsize=(10, 5))
plt.scatter(titanic['Age'], titanic['Fare'], s=10, c='blue')
plt.title('Relation ship Fare-Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Method 2 - seaborn
# your code here
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Fare', data=titanic)
plt.title('Relation ship Fare-Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %%
sns.set(style = 'white')
mascara = np.triu(np.ones_like(titanic.corr(), dtype = bool))
cmap = sns.diverging_palette(0, 10, as_cmap = True) 

sns.heatmap(titanic.corr(), 
            mask=mascara,
            cmap=cmap,
            vmax=1,
            vmin=-1,
            center=0,
            square=True,
            linewidth=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True
           )

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
plt.figure(figsize=(10, 5))
sns.boxplot(x='Pclass', y='Age', data=titanic)
plt.title(' Age Depending on PClass')
plt.xlabel('PClass')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
plot = sns.FacetGrid(titanic, col='Gender', height=5)

plot.map(sns.histplot, 'Age', kde=True)
# Out:
# C:\Users\jaime\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
