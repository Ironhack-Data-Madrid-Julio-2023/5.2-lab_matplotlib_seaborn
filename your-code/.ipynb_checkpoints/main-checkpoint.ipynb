# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import pylab as plt
import seaborn as sns

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# Download the CSV file containing the happiness data for further analysis.

fitbit = pd.read_csv("/Users/david/Desktop/IronHack/5.2-lab_matplotlib_seaborn/data/Fitbit2.csv")

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here

fitbit.groupby('Months_encoded').mean()['Steps']
# Out:
# /var/folders/x2/68m0f_l16x5bzxl95_y3qn3m0000gp/T/ipykernel_23207/2973912216.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fitbit.groupby('Months_encoded').mean()['Steps']
# Months_encoded
# 1      9892.064516
# 2      8922.866667
# 3     10312.935484
# 4     13079.033333
# 5     10620.096774
# 6     12536.166667
# 7      9193.322581
# 8     11584.774194
# 9      9191.333333
# 10     8272.451613
# 11     9467.466667
# 12     8470.064516
# Name: Steps, dtype: float64

# %%
plt.figure(figsize=(12, 4))

fitbit.groupby('Months_encoded').mean()['Steps'].plot(kind='bar')

plt.savefig('/Users/david/Desktop/IronHack/5.2-lab_matplotlib_seaborn/figures/fig1.png')
# Out:
# /var/folders/x2/68m0f_l16x5bzxl95_y3qn3m0000gp/T/ipykernel_23207/597373720.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fitbit.groupby('Months_encoded').mean()['Steps'].plot(kind='bar')

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
fitbit.groupby('Months_encoded').mean()['Work_or_Weekend']
# Out:
# /var/folders/x2/68m0f_l16x5bzxl95_y3qn3m0000gp/T/ipykernel_23207/3626297228.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fitbit.groupby('Months_encoded').mean()['Work_or_Weekend']
# Months_encoded
# 1     0.677419
# 2     0.733333
# 3     0.741935
# 4     0.700000
# 5     0.677419
# 6     0.733333
# 7     0.741935
# 8     0.677419
# 9     0.733333
# 10    0.709677
# 11    0.700000
# 12    0.741935
# Name: Work_or_Weekend, dtype: float64

# %%
plt.figure(figsize=(12, 4))

fitbit.groupby('Months_encoded').mean()['Work_or_Weekend'].plot(kind='bar')

plt.savefig('/Users/david/Desktop/IronHack/5.2-lab_matplotlib_seaborn/figures/fig2.png')
# Out:
# /var/folders/x2/68m0f_l16x5bzxl95_y3qn3m0000gp/T/ipykernel_23207/1271898797.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fitbit.groupby('Months_encoded').mean()['Work_or_Weekend'].plot(kind='bar')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit_sublist = fitbit[["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]]

for e in fitbit_sublist:
    
    fitbit.plot.scatter(x=e, y='Steps');

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("/Users/david/Desktop/IronHack/5.2-lab_matplotlib_seaborn/data/titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(include='number').columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here

titanic.select_dtypes(include='category').columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

def set_figure_size():
    plt.style.use("classic")
    plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
set_figure_size()
titanic["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot the distribution with different bin sizes
bins = [10, 20, 50]
for i, bin_size in enumerate(bins):
    axs[i].hist(titanic["Age"], bins=bin_size)

# Display the plot
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# It is more or less detailed
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# sns.countplot(x=titanic.Age)

sns.histplot(data=titanic, x="Age", bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

titanic['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Method 2 - seaborn
# your code here

sns.countplot(x=titanic.Gender)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.countplot(x=titanic.Pclass)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

plt.boxplot(titanic["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1767b5840>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1767b5d80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1767b55a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1767b62c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1767b6560>],
#  'means': []}

# %%
"""
your comments here
"""

# There are lots of outlayers. The median in almost 30 years old.
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# There are lots of outlayers. The median in almost 30 years old.
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

fig, axs = plt.subplots(2, 1, figsize=(8, 10))

# Violin plot
sns.violinplot(data=titanic, y="Age", ax=axs[0])
axs[0].set_ylabel("Age")
axs[0].set_title("Distribution of Age")

# Box plot
sns.boxplot(data=titanic, x="Age", ax=axs[1])
axs[1].set_xlabel("Age")
axs[1].set_title("Summary Statistics of Age")
# Out:
# Text(0.5, 1.0, 'Summary Statistics of Age')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# Looks like a normal distribution if you delete the outlayers
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

titanic[["Fare","Age"]].corr()
# Out:
#           Fare       Age
# Fare  1.000000  0.171355
# Age   0.171355  1.000000

# %%
plt.scatter(titanic["Fare"], titanic["Age"])

# %%
# Method 2 - seaborn
# your code here

sns.scatterplot(data=titanic, x="Fare", y="Age")
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

pd.plotting.scatter_matrix(titanic);

# %%
sns.pairplot(titanic)

# %%
corr = titanic.corr()

sns.set(style='white')     # estilo blanco

mascara = np.triu(np.ones_like(corr, dtype=bool))   # mascara

cmap = sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(corr,          # datos
            mask=mascara,  # mascara
            cmap=cmap,     # paleta de colores
            vmax=1,           # maximo vertical
            vmin=-1,          # minimo vertical
            center=0,         # centro
            square=True,      # cuadrado el dato pintado
            linewidth=0.5,    # ancho de la linea
            
            cbar_kws={'shrink': 0.5},  # barra de color
            annot=True                 # anotacion, el numero escrito
           );
# Out:
# /var/folders/x2/68m0f_l16x5bzxl95_y3qn3m0000gp/T/ipykernel_23207/3370248793.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = titanic.corr()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# Pcalss and fare
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

sns.boxplot(x='Pclass', y='Age', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

sns.boxplot(x='Gender', y='Age', data=titanic)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
x = sns.FacetGrid(titanic, row='Gender')
x.map(sns.histplot, 'Age', kde=True)
