# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# %pip install folium
# Out:
# ...
#      -------------------------------------- 102.3/102.3 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Libraries
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)  # me muestre todas las columnas
#pd.set_option('display.max_rows', None)  # me muestre todas las filas

import folium

import pylab as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit_original = pd.read_csv(r'..\data\Fitbit2.csv')
fitbit = fitbit_original.copy()
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %%
fitbit.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        367 non-null    object
#  1   Calorie burned              367 non-null    int64
#  2   Steps                       367 non-null    int64
#  3   Distance                    367 non-null    float64
#  4   Floors                      367 non-null    int64
#  5   Minutes Sedentary           367 non-null    float64
#  6   Minutes Lightly Active      367 non-null    int64
#  7   Minutes Fairly Active       367 non-null    int64
#  8   Minutes Very Active         367 non-null    int64
#  9   Activity Calories           367 non-null    int64
#  10  MinutesOfSleep              367 non-null    int64
#  11  MinutesOfBeingAwake         367 non-null    int64
#  12  NumberOfAwakings            367 non-null    int64
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED

avg_steps_by_month = fitbit.groupby('Months_encoded')['Steps'].mean()

fig, ax = plt.subplots(figsize=(12, 4))
avg_steps_by_month.plot(kind='bar', ax=ax, color='blue')
ax.set_xlabel('Month')
ax.set_ylabel('Average Steps')
ax.set_title('Average Number of Steps by Month');

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND

activity_by_weekday = fitbit.groupby('Work_or_Weekend')['Steps'].median()

fig, ax = plt.subplots(figsize=(12, 4))
activity_by_weekday.plot(kind='pie', ax=ax, labels=['Workdays', 'Weekends'], autopct='%1.1f%%', colors=['green', 'orange'])
ax.set_ylabel('')
ax.set_title('Activity on Weekends vs Workdays');

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
features = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, feature in enumerate(features):
    ax = axes[i]
    ax.scatter(fitbit[feature], fitbit['Steps'], alpha=0.5)
    ax.set_xlabel(feature)
    ax.set_ylabel('Steps')
    ax.set_title(f"{feature} vs Steps")

plt.tight_layout()

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic_original = pd.read_csv(r'..\data\titanic.csv')
titanic = titanic_original.copy()
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 489.8 KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES

titanic.select_dtypes(exclude=object)
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES

titanic.select_dtypes(include=object)
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')

fig, ax = plt.subplots(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age); # Histograma

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 6))

# Plot distribution with bin size of 10
axes[0].hist(titanic['Age'], bins=10)
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Distribution (bin=10)')

# Plot distribution with bin size of 20
axes[1].hist(titanic['Age'], bins=20)
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Distribution (bin=20)')

# Plot distribution with bin size of 50
axes[2].hist(titanic['Age'], bins=50)
axes[2].set_xlabel('Age')
axes[2].set_ylabel('Frequency')
axes[2].set_title('Distribution (bin=50)')

plt.tight_layout()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Cuantas más barras tengo para representar una grafica los datos son más correctos, se van ajustando cada vez más, 
mientras que cuando hay pocas barras hace una estimación de los datos reales.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age,
            bins=60,          # nº de barras 
            kde=True,         # kde=kernel density estimation (la linea)
            element='step',   # linea negra
            );

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Count the occurrences of each gender
gender_counts = titanic['Gender'].value_counts()

# Create a bar plot using Matplotlib

plt.bar(gender_counts.index, gender_counts.values)

# Set the axis labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')

# Show the plot
plt.show()

# %%
# Method 2 - seaborn
sns.countplot(x=titanic.Gender);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass);

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# Create a box plot of the 'Age' feature
sns.boxplot(data=titanic, y='Age')

# Set the y-axis label and title
plt.ylabel('Age')
plt.title('Summary Statistics of Age');

# %%
"""
Boxplot
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Con este tipo de gráfico podemos ver que los valores que están dentro de la caja son los que coinciden con la moda y los que están fuera del rango intercuartil son outliers
"""
# Out:
# '\nCon este tipo de gráfico podemos ver que los valores que están dentro de la caja son los que coinciden con la moda y los que están fuera del rango intercuartil son outliers\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# Violin plot

sns.violinplot(data=titanic.Age, color='orange');

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Visualiza la densidad de probabilidad además de la distribución de los datos.
"""
# Out:
# '\nVisualiza la densidad de probabilidad además de la distribución de los datos.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
titanic.plot.scatter(x='Fare', y='Age');

# %%
# Method 2 - seaborn
sns.scatterplot(data=titanic,
                x='Fare',
                y='Age')

plt.xticks(rotation=35);

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# Calculate the correlation matrix
correlation_matrix = titanic.corr()

mascara = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Plot the correlation matrix as a heatmap
sns.heatmap(correlation_matrix,  mask=mascara, annot=True, cmap='coolwarm', vmin=-1, vmax=1)

# Set the title of the plot
plt.title('Correlation Matrix');

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Parch and SibSp; survived and Fare. They are related because people who paid more got a higher class ticket; 
therefore, when evacuating the survivors, they had priority
"""
# Out:
# '\nParch and SibSp\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
sns.boxplot(data=titanic, x='Pclass', y='Age')

plt.xlabel('Pclass')
plt.ylabel('Age')
plt.title('Summary Statistics of Age by Passenger Class')

plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here# Create a FacetGrid with Gender as the column
g = sns.FacetGrid(titanic, col='Gender', height=5, aspect=1.2)

# Map the histogram plot to the 'Age' column
g.map(sns.histplot, 'Age', bins=10)

# Set the axis labels and title
g.set_axis_labels('Age', 'Frequency')
g.fig.suptitle('Distribution of Age by Gender')

# Adjust the spacing between subplots
g.tight_layout()

# Show the plot
plt.show()
