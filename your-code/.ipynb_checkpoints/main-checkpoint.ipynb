# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
pd.set_option('display.max_columns', None)
# Your Code Here

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
pasos_mensuales_mediana = fitbit.groupby('Months_encoded')['Steps'].median()
'''
ax = plt.subplots(figsize=(12, 4))
plt.sca(ax)'''

pasos_mensuales_mediana.plot(kind='bar')

plt.xlabel('Month')
plt.ylabel('Median Steps')
plt.title('Median Steps by Month')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.savefig('figures/monthly_steps_median.png')
plt.show()

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND

work_median_steps = fitbit.groupby('Work_or_Weekend')['Steps'].median()


work_median_steps.plot(kind='bar')


plt.xlabel('Type of Day')
plt.ylabel('Median Steps')
plt.title('Median Steps: Workdays vs Weekend')
plt.xticks(ticks=range(2), rotation=0)
plt.savefig('figures/work_median_steps.png')

plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
x = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

fig, axs = plt.subplots(1, 3, figsize=(18, 6))

for i, x in enumerate(x):
    axs[i].scatter(fitbit[x], fitbit['Steps'])

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include=('float64','int64'))
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age']);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fgs, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].hist(titanic['Age'], bins= 10)
axs[1].hist(titanic['Age'], bins= 20)
axs[2].hist(titanic['Age'], bins= 50);

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Una mejor imagen de la evolución de los datos cuanto mayor son las barras
"""
# Out:
# '\nUna mejor imagen de la evolución de los datos cuanto mayor son las barras\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(titanic['Age'], bins=30);

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - Seaborn
plt.figure(figsize=(8, 4))
sns.countplot(x='Gender', data=titanic)
plt.title('Distribution of Gender in the Titanic Dataset')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Method 2 - Matplotlib
plt.figure(figsize=(8, 6))
plt.hist(titanic['Gender'])
plt.title('Distribution of Gender in the Titanic Dataset')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Pclass', data=titanic)
plt.title('Distribution of Passenger Class in the Titanic Dataset')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=titanic['Age'])
plt.title('Summary Statistics of Age in the Titanic Dataset')
plt.xlabel('Age')
plt.show()

# %%
"""
La mayoría del pasaje estaba entre 23 y 38 años
"""
# Out:
# '\nLa mayoría del pasaje estaba entre 23 y 38 años\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
sns.violinplot(x="Age", data = titanic);

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Nos viene a decir lo mismo pero nos muestra como se distribuyen mejor los años del pasaje
"""
# Out:
# '\nNos viene a decir lo mismo pero nos muestra como se distribuyen mejor los años del pasaje\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.figure(figsize=(10, 6))
plt.scatter(titanic['Age'], titanic['Fare'], s=10, c='blue')
plt.title('Relationship Between Age and Fare in the Titanic Dataset')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Method 2 - seaborn
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Fare', data=titanic, scatter_kws={'s': 10}, line_kws={'color': 'red'})
plt.title('Relationship Between Age and Fare in the Titanic Dataset')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
titanic_corr = titanic.corr(method='pearson')
# Out:
# /var/folders/26/6wvprncs6vnd3p7b5kc3_r0c0000gn/T/ipykernel_40757/3591393704.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic_corr = titanic.corr(method='pearson')

# %%
sns.set(style='white')     # estilo blanco

mascara = np.triu(np.ones_like(titanic_corr, dtype=bool))   # mascara

cmap = sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores


sns.heatmap(titanic_corr,          # datos
            mask=mascara,  # mascara
            cmap=cmap,     # paleta de colores
            vmax=1,           # maximo vertical
            vmin=-1,          # minimo vertical
            center=0,         # centro
            square=True,      # cuadrado el dato pintado
            linewidth=0.5,    # ancho de la linea
            
            cbar_kws={'shrink': 0.5},  # barra de color
            annot=True                 # anotacion, el numero escrito
           );

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Las características más correlacionadas en el conjunto de datos del Titanic son "Fare" y "Pclass", con un coeficiente de correlación de aproximadamente -0.5587.
"""
# Out:
# '\nLas características más correlacionadas en el conjunto de datos del Titanic son "Fare" y "Pclass", con un coeficiente de correlación de aproximadamente -0.5587.\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Pclass', y='Age', data=titanic, palette='rainbow')
plt.title('Summary Statistics of Age Depending on Passenger Class in the Titanic Dataset')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
graf = sns.FacetGrid(titanic, col='Gender', height=5)

graf.map(sns.histplot, 'Age', kde=True);
